# %% [markdown]
# ## Содержание
#
# 1. [Восстановить IP-адрес](#Восстановить_IP-адрес)
#     1. [Подсчет количества адресов в сети](#Подсчет_количества_адресов_в_сети)
#
#
# Статья про кодировки на хабре: [Что нужно знать каждому разработчику о кодировках и наборах символов для работы с текстом](https://habrahabr.ru/post/158639/)

# %% [markdown]
# <a name='Восстановить_IP-адрес'></a>
# ### 1. Восстановить IP-адрес

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <a name='Подсчет_количества_адресов_в_сети'></a>
# ### 2. Подсчет количества адресов в сети

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Восстановить URL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Определение адреса сети

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. Определение маски

# %% [markdown]
# ![image.png](attachment:image.png)
